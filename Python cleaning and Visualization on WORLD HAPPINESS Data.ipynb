# %% [markdown]
# WORLD HAPPINESS
#
# Research Objective:
#     To identify the geographical, demographic, and/or economic factors that contribute to a happier life.

# %% [markdown]
# FIELDS
#
# Country:Name of country
#
# Happiness score: Average of response to the primary life evaluation question
# Gdp_per_capita: the extent to ehich gdp contributes to the calculation of the happiness score
# Family: the extent to which family contributes to the calculation of the happiness score
# Health: the extent to which life expentancy contributed to the calculation of the happiness score
# Freedom: the extent to which  freedom contributed to the calculation of the happiness score
# Generosity: A numerical value calculated based on polls participant perception of generosity in their country
# Government trust: The extent to which perception of corruption contributes to the happiness score
# Dystopial residual: a score baswed on a hypothetical comparision to the world saddest country
# Continent: Region of the country
# Year: Date of each findings

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Imported my Libraries

# %%
df = pd.read_csv("WorldHappiness_Corruption_2015_2020.csv")
df
# Out:
#          Country  happiness_score  gdp_per_capita    family    health  \
# 0         Norway           7.5370        1.616463  1.533524  0.796667
# 1        Denmark           7.5220        1.482383  1.551122  0.792566
# 2        Iceland           7.5040        1.480633  1.610574  0.833552
# 3    Switzerland           7.4940        1.564980  1.516912  0.858131
# 4        Finland           7.4690        1.443572  1.540247  0.809158
# ..           ...              ...             ...       ...       ...
# 787     Botswana           3.4789        0.997549  0.000000  0.494102
# 788     Tanzania           3.4762        0.457163  0.000000  0.442678
# 789       Rwanda           3.3123        0.343243  0.000000  0.572383
# 790     Zimbabwe           3.2992        0.425564  0.000000  0.375038
# 791  Afghanistan           2.5669        0.300706  0.000000  0.266052
#
#       freedom  generosity  government_trust  dystopia_residual continent  \
# ...

# %% [markdown]
# Imported the dataset (World Happiness Corruption into python)

# %%
df.shape
# Out:
# (792, 13)

# %% [markdown]
# There are 792 rows and 13 columns in the World Happiness Dataset

# %%
#getting more infomation about the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            792 non-null    object
#  1   happiness_score    792 non-null    float64
#  2   gdp_per_capita     792 non-null    float64
#  3   family             792 non-null    float64
#  4   health             792 non-null    float64
#  5   freedom            792 non-null    float64
#  6   generosity         792 non-null    float64
#  7   government_trust   792 non-null    float64
#  8   dystopia_residual  792 non-null    float64
#  9   continent          792 non-null    object
#  10  Year               792 non-null    int64
#  11  social_support     792 non-null    float64
#  12  cpi_score          792 non-null    int64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 80.6+ KB

# %%
#Dropping duplicates in my dataset

df.drop_duplicates()
# Out:
#          Country  happiness_score  gdp_per_capita    family    health  \
# 0         Norway           7.5370        1.616463  1.533524  0.796667
# 1        Denmark           7.5220        1.482383  1.551122  0.792566
# 2        Iceland           7.5040        1.480633  1.610574  0.833552
# 3    Switzerland           7.4940        1.564980  1.516912  0.858131
# 4        Finland           7.4690        1.443572  1.540247  0.809158
# ..           ...              ...             ...       ...       ...
# 787     Botswana           3.4789        0.997549  0.000000  0.494102
# 788     Tanzania           3.4762        0.457163  0.000000  0.442678
# 789       Rwanda           3.3123        0.343243  0.000000  0.572383
# 790     Zimbabwe           3.2992        0.425564  0.000000  0.375038
# 791  Afghanistan           2.5669        0.300706  0.000000  0.266052
#
#       freedom  generosity  government_trust  dystopia_residual continent  \
# ...

# %% [markdown]
# Dropped all the duplicates in the dataset

# %%
#describing the data

df.describe()
# Out:
#        happiness_score  gdp_per_capita      family      health     freedom  \
# count       792.000000      792.000000  792.000000  792.000000  792.000000
# mean          5.473310        0.929217    0.504998    0.648691    0.427016
# std           1.124726        0.385774    0.552736    0.232261    0.148003
# min           2.566900        0.000000    0.000000    0.000000    0.000000
# 25%           4.590750        0.644242    0.000000    0.510070    0.325433
# 50%           5.485500        0.994544    0.000000    0.685397    0.439621
# 75%           6.300500        1.228677    1.040410    0.815641    0.546280
# max           7.808700        2.096000    1.610574    1.141000    0.724000
#
#        generosity  government_trust  dystopia_residual         Year  \
# count  792.000000        792.000000         792.000000   792.000000
# mean     0.212440          0.125720           1.379277  2017.500000
# std      0.121660          0.109032           1.075276     1.708904
# ...

# %% [markdown]
# I checked the measure of dispersion in the dataset to check for any outliers

# %%
#listing the fields in the dataset

df.columns.tolist()
# Out:
# ['Country',
#  'happiness_score',
#  'gdp_per_capita',
#  'family',
#  'health',
#  'freedom',
#  'generosity',
#  'government_trust',
#  'dystopia_residual',
#  'continent',
#  'Year',
#  'social_support',
#  'cpi_score']

# %% [markdown]
# 'Country','happiness_score','gdp_per_capita','family','health','freedom','generosity','government_trust','dystopia_residual',
# 'continent', 'Year','social_support','cpi_score' ARE the columns in the dataset

# %%
#the continents in the field "Continent"

df["continent"].unique().tolist()
# Out:
# ['Europe', 'North America', 'Australia', 'Asia', 'South America', 'Africa']

# %% [markdown]
# 'Europe', 'North America', 'Australia', 'Asia', 'South America', 'Africa' ARE the continents present in the dataset

# %%
#The average Happinness_score

mean_happiness= df["happiness_score"].mean()
mean_happiness
# Out:
# 5.473309846702018

# %% [markdown]
# 5.4 is the average happiness score

# %%
#The average Gdp_per_capita

mean_gdp_per_capita= df["gdp_per_capita"].mean()
mean_gdp_per_capita
# Out:
# 0.929217068271465

# %% [markdown]
# 0.93 is the average gdp_per_capita

# %%
#The average Health

mean_health= df["health"].mean()
mean_health
# Out:
# 0.6486912089419189

# %% [markdown]
# 0.65 is the average health score

# %%
df["happiness_score"].agg(["min","max"])
# Out:
# min    2.5669
# max    7.8087
# Name: happiness_score, dtype: float64

# %% [markdown]
# 2.5669 is the minimum happiness score while 7.8087 is the highest happiness score

# %%
#Dropping the Null Values

Null_values = pd.isnull(df).sum()
Null_values
# Out:
# Country              0
# happiness_score      0
# gdp_per_capita       0
# family               0
# health               0
# freedom              0
# generosity           0
# government_trust     0
# dystopia_residual    0
# continent            0
# Year                 0
# social_support       0
# cpi_score            0
# dtype: int64

# %% [markdown]
# Dropped all the null values in the dataset

# %%
#Sorting the values (Displaying only the top 10)

sort_value = df.sort_values(by = 'happiness_score', ascending = False)
sort_value.head(10)
# Out:
#          Country  happiness_score  gdp_per_capita   family    health  \
# 660      Finland           7.8087        1.285190  0.00000  0.961271
# 264      Finland           7.7690        1.340000  0.00000  0.986000
# 661      Denmark           7.6456        1.326949  0.00000  0.979333
# 396      Finland           7.6320        1.305000  0.00000  0.874000
# 265      Denmark           7.6000        1.383000  0.00000  0.996000
# 397       Norway           7.5940        1.456000  0.00000  0.861000
# 132  Switzerland           7.5870        1.396510  1.34951  0.941430
# 133      Iceland           7.5610        1.302320  1.40223  0.947840
# 662  Switzerland           7.5599        1.390774  0.00000  1.040533
# 398      Denmark           7.5550        1.351000  0.00000  0.868000
#
#       freedom  generosity  government_trust  dystopia_residual continent  \
# 660  0.662317    0.159670          0.477857           2.762835    Europe
# ...

# %% [markdown]
# displaying the highest 10 happiness score

# %%
#Sorting the values (Displaying only the top 10)

sort_value = df.sort_values(by = 'happiness_score', ascending = True)
sort_value.head(10)
# Out:
#          Country  happiness_score  gdp_per_capita    family    health  \
# 791  Afghanistan           2.5669        0.300706  0.000000  0.266052
# 263         Togo           2.8390        0.208680  0.139950  0.284430
# 131      Burundi           2.9050        0.091623  0.629794  0.151611
# 659      Burundi           2.9050        0.068310  0.234420  0.157470
# 527      Burundi           2.9050        0.091000  0.000000  0.145000
# 262      Burundi           2.9050        0.015300  0.415870  0.223960
# 395  Afghanistan           3.2030        0.350000  0.000000  0.361000
# 394     Tanzania           3.2310        0.476000  0.000000  0.499000
# 790     Zimbabwe           3.2992        0.425564  0.000000  0.375038
# 658         Togo           3.3030        0.281230  0.000000  0.248110
#
#       freedom  generosity  government_trust  dystopia_residual continent  \
# 791  0.000000    0.135235          0.001226           1.507236      Asia
# ...

# %% [markdown]
# displaying the lowest 10 happiness score

# %%
#Sorting the values (Displaying only the top 10)

sort_value = df.sort_values(by = 'gdp_per_capita', ascending = False)
sort_value.head(10)
# Out:
#                   Country  happiness_score  gdp_per_capita    family  \
# 415  United Arab Emirates            6.774        2.096000  0.000000
# 17             Luxembourg            6.863        1.741944  1.457584
# 546            Luxembourg            6.871        1.697520  1.039990
# 24              Singapore            6.572        1.692278  1.353814
# 548             Singapore            6.739        1.645550  0.867580
# 34                 Kuwait            6.105        1.632952  1.259699
# 20   United Arab Emirates            6.648        1.626343  1.266410
# 563                Kuwait            6.239        1.617140  0.877580
# 0                  Norway            7.537        1.616463  1.533524
# 277            Luxembourg            7.090        1.609000  0.000000
#
#        health   freedom  generosity  government_trust  dystopia_residual  \
# 415  0.670000  0.284000    0.186000          0.312000           0.000000
# ...

# %% [markdown]
# displaying the highest 10 gdp_per_capita

# %%
#Sorting the values (Displaying only the top 10)

sort_value = df.sort_values(by = 'gdp_per_capita', ascending = True)
sort_value.head(10)
# Out:
#      Country  happiness_score  gdp_per_capita   family    health   freedom  \
# 781  Burundi           3.7753         0.00000  0.00000  0.295213  0.275399
# 262  Burundi           2.9050         0.01530  0.41587  0.223960  0.118500
# 242   Malawi           4.2920         0.01604  0.41134  0.225620  0.430540
# 387  Burundi           3.7750         0.04600  0.00000  0.380000  0.220000
# 659  Burundi           2.9050         0.06831  0.23442  0.157470  0.043200
# 252    Niger           3.8450         0.06940  0.77265  0.297070  0.476920
# 230  Liberia           4.5710         0.07120  0.78968  0.342010  0.285310
# 385  Liberia           3.9750         0.07300  0.00000  0.443000  0.370000
# 523  Liberia           3.4950         0.07600  0.00000  0.267000  0.419000
# 640   Malawi           4.1560         0.08709  0.14700  0.293640  0.414300
#
#      generosity  government_trust  dystopia_residual continent  Year  \
# 781    0.187402          0.212187           2.401507    Africa  2020
# ...

# %% [markdown]
# displaying the lowest 10 gdp_per_capita

# %%
#Sorting the values (Displaying only the top 10)

sort_value = df.sort_values(by = 'health', ascending = False)
sort_value.head(10)
# Out:
#          Country  happiness_score  gdp_per_capita  family    health   freedom  \
# 294    Singapore           6.2620        1.572000     0.0  1.141000  0.556000
# 688    Singapore           6.3771        1.519580     0.0  1.137814  0.635317
# 316        Japan           5.8860        1.327000     0.0  1.088000  0.445000
# 717        Japan           5.8708        1.266724     0.0  1.072881  0.495466
# 290        Spain           6.3540        1.286000     0.0  1.062000  0.362000
# 269  Switzerland           7.4800        1.452000     0.0  1.052000  0.572000
# 685        Spain           6.4009        1.230535     0.0  1.051343  0.425984
# 286       France           6.5920        1.324000     0.0  1.045000  0.436000
# 308       Cyprus           6.0460        1.263000     0.0  1.042000  0.406000
# 662  Switzerland           7.5599        1.390774     0.0  1.040533  0.628954
#
#      generosity  government_trust  dystopia_residual continent  Year  \
# ...

# %% [markdown]
# displaying the highest 10 health score

# %%
#Sorting the values (Displaying only the top 10)

sort_value = df.sort_values(by = 'health', ascending = True)
sort_value.head(10)
# Out:
#           Country  happiness_score  gdp_per_capita    family    health  \
# 622  Sierra Leone            4.635        0.364850  0.628000  0.000000
# 494  Sierra Leone            4.571        0.256000  0.000000  0.000000
# 235  Sierra Leone            4.507        0.330240  0.955710  0.000000
# 93   Sierra Leone            4.709        0.368421  0.984136  0.005565
# 647          Chad            3.763        0.422140  0.631780  0.038240
# 118          Chad            3.936        0.438013  0.953856  0.041135
# 239      Botswana            4.332        0.993550  1.104640  0.047760
# 477       Nigeria            5.155        0.689000  0.000000  0.048000
# 615       Nigeria            4.875        0.752160  0.644980  0.051080
# 509          Chad            4.301        0.358000  0.000000  0.053000
#
#       freedom  generosity  government_trust  dystopia_residual continent  \
# 622  0.306850    0.238970          0.081960           3.014020    Africa
# ...

# %% [markdown]
# displaying the lowest 10 health score

# %%
#Sorting the values (Displaying only the top 10)

sort_value = df.sort_values(by = 'family', ascending = False)
sort_value.head(10)
# Out:
#         Country  happiness_score  gdp_per_capita    family    health  \
# 2       Iceland            7.504        1.480633  1.610574  0.833552
# 14      Ireland            6.977        1.535707  1.558231  0.809783
# 1       Denmark            7.522        1.482383  1.551122  0.792566
# 42   Uzbekistan            5.971        0.786441  1.548969  0.498273
# 7   New Zealand            7.314        1.405706  1.548195  0.816760
# 4       Finland            7.469        1.443572  1.540247  0.809158
# 0        Norway            7.537        1.616463  1.533524  0.796667
# 31        Spain            6.403        1.384398  1.532091  0.888961
# 3   Switzerland            7.494        1.564980  1.516912  0.858131
# 9     Australia            7.284        1.484415  1.510042  0.843887
#
#      freedom  generosity  government_trust  dystopia_residual  continent  \
# 2   0.627163    0.475540          0.153527           2.322715     Europe
# ...

# %% [markdown]
# displaying the highest 10 family score

# %%
#Sorting the values (Displaying only the top 10)

sort_value = df.sort_values(by = 'family', ascending = True)
sort_value.head(10)
# Out:
#          Country  happiness_score  gdp_per_capita  family  health  freedom  \
# 395  Afghanistan            3.203           0.350     0.0   0.361    0.000
# 436       Kuwait            6.083           1.474     0.0   0.675    0.554
# 437     Thailand            6.072           1.016     0.0   0.707    0.637
# 438        Italy            6.000           1.264     0.0   0.946    0.281
# 439      Ecuador            5.973           0.889     0.0   0.736    0.556
# 440    Lithuania            5.952           1.197     0.0   0.716    0.350
# 441     Slovenia            5.948           1.219     0.0   0.856    0.633
# 442      Romania            5.945           1.116     0.0   0.726    0.528
# 435   Uzbekistan            6.096           0.719     0.0   0.605    0.724
# 443       Latvia            5.933           1.148     0.0   0.671    0.363
#
#      generosity  government_trust  dystopia_residual      continent  Year  \
# ...

# %% [markdown]
# displaying the lowest 10 family score

# %%
#Sorting the values (Displaying only the top 10)

sort_value = df.sort_values(by = 'government_trust', ascending = False)
sort_value.head(10)
# Out:
#        Country  happiness_score  gdp_per_capita    family    health   freedom  \
# 260     Rwanda           3.4650        0.222080  0.773700  0.428640  0.592010
# 688  Singapore           6.3771        1.519580  0.000000  1.137814  0.635317
# 655     Rwanda           3.5150        0.328460  0.615860  0.318650  0.543200
# 661    Denmark           7.6456        1.326949  0.000000  0.979333  0.665040
# 154  Singapore           6.7980        1.521860  1.020000  1.025250  0.542520
# 789     Rwanda           3.3123        0.343243  0.000000  0.572383  0.604088
# 134    Denmark           7.5270        1.325480  1.360580  0.874640  0.649380
# 660    Finland           7.8087        1.285190  0.000000  0.961271  0.662317
# 548  Singapore           6.7390        1.645550  0.867580  0.947190  0.487700
# 24   Singapore           6.5720        1.692278  1.353814  0.949492  0.549841
#
#      generosity  government_trust  dystopia_residual continent  Year  \
# ...

# %% [markdown]
# displaying the highest 10 government_trust

# %%
#Sorting the values (Displaying only the top 10)

sort_value = df.sort_values(by = 'government_trust', ascending = True)
sort_value.head(10)
# Out:
#                     Country  happiness_score  gdp_per_capita    family  \
# 479  Bosnia and Herzegovina           5.1290        0.915000  0.000000
# 81   Bosnia and Herzegovina           5.1820        0.982409  1.069336
# 745                Bulgaria           5.1015        1.046555  0.000000
# 196               Indonesia           5.3990        0.828270  1.087080
# 328                 Moldova           5.5290        0.685000  0.000000
# 602  Bosnia and Herzegovina           5.1630        0.933830  0.643670
# 455                 Moldova           5.6400        0.657000  0.000000
# 703                 Romania           6.1237        1.120402  0.000000
# 442                 Romania           5.9450        1.116000  0.000000
# 724  Bosnia and Herzegovina           5.6741        0.918395  0.000000
#
#        health   freedom  generosity  government_trust  dystopia_residual  \
# 479  0.758000  0.280000    0.216000          0.000000           0.000000
# ...

# %% [markdown]
# displaying the lowest 10 government_trust

# %%
#Sorting by year

sort_year= df.groupby(['Year', 'continent', 'Country']).agg({'happiness_score':['max','min']})
sort_year
# Out:
#                                 happiness_score
#                                             max     min
# Year continent     Country
# 2015 Africa        Algeria               5.8720  5.8720
#                    Benin                 3.6570  3.6570
#                    Botswana              3.7660  3.7660
#                    Burkina Faso          4.0320  4.0320
#                    Burundi               2.9050  2.9050
# ...                                         ...     ...
# 2020 South America Panama                6.3048  6.3048
#                    Paraguay              5.6921  5.6921
#                    Peru                  5.7968  5.7968
#                    Uruguay               6.4401  6.4401
#                    Venezuela             5.0532  5.0532
#
# [792 rows x 2 columns]

# %%
#Sorting by year

sort_continent= df.groupby(['Year']).agg({'happiness_score':['max', 'min']})
sort_continent
# Out:
#      happiness_score
#                  max     min
# Year
# 2015          7.5370  2.9050
# 2016          7.5870  2.8390
# 2017          7.7690  3.2030
# 2018          7.6320  2.9050
# 2019          7.5260  2.9050
# 2020          7.8087  2.5669

# %% [markdown]
# dispalying the maximum and minimum happiness score per year

# %%
#Sorting by year

sort_continent= df.groupby(['Year']).agg({'health':['max','min']})
sort_continent
# Out:
#         health
#            max       min
# Year
# 2015  0.949492  0.005565
# 2016  1.025250  0.000000
# 2017  1.141000  0.192000
# 2018  1.008000  0.000000
# 2019  0.947190  0.000000
# 2020  1.137814  0.108744

# %% [markdown]
# dispalying the maximum and minimum health score per year

# %%
#Sorting by year

sort_continent= df.groupby(['Year']).agg({'gdp_per_capita':['max','min']})
sort_continent
# Out:
#      gdp_per_capita
#                 max       min
# Year
# 2015       1.741944  0.091623
# 2016       1.563910  0.015300
# 2017       1.609000  0.046000
# 2018       2.096000  0.076000
# 2019       1.697520  0.068310
# 2020       1.536676  0.000000

# %% [markdown]
# dispalying the maximum and minimum gdp_per_capita score per year

# %%
#Sorting by year

sort_continent= df.groupby(['Year']).agg({'freedom':['max','min']})
sort_continent
# Out:
#        freedom
#            max      min
# Year
# 2015  0.658249  0.03037
# 2016  0.669730  0.00000
# 2017  0.631000  0.00000
# 2018  0.724000  0.02500
# 2019  0.608480  0.04320
# 2020  0.693270  0.00000

# %% [markdown]
# dispalying the maximum and minimum freedom score per year

# %%
df.groupby(["continent","Country","Year"]).max().sort_values(by="happiness_score",ascending = False)
# Out:
#                             happiness_score  gdp_per_capita    family  \
# continent Country     Year
# Europe    Finland     2020           7.8087        1.285190  0.000000
#                       2017           7.7690        1.340000  0.000000
#           Denmark     2020           7.6456        1.326949  0.000000
#           Finland     2018           7.6320        1.305000  0.000000
#           Denmark     2017           7.6000        1.383000  0.000000
# ...                                     ...             ...       ...
# Africa    Burundi     2018           2.9050        0.091000  0.000000
#                       2019           2.9050        0.068310  0.234420
#                       2015           2.9050        0.091623  0.629794
#           Togo        2016           2.8390        0.208680  0.139950
# Asia      Afghanistan 2020           2.5669        0.300706  0.000000
#
#                               health   freedom  generosity  government_trust  \
# ...

# %% [markdown]
# grouping the highest happiness score by continent, country and year

# %%
df.groupby(["continent","Country","Year"]).max().sort_values(by="health",ascending = False)
# Out:
#                              happiness_score  gdp_per_capita    family  \
# continent Country      Year
# Asia      Singapore    2017           6.2620        1.572000  0.000000
#                        2020           6.3771        1.519580  0.000000
#           Japan        2017           5.8860        1.327000  0.000000
#                        2020           5.8708        1.266724  0.000000
# Europe    Spain        2017           6.3540        1.286000  0.000000
# ...                                      ...             ...       ...
# Africa    Chad         2019           3.7630        0.422140  0.631780
#           Sierra Leone 2015           4.7090        0.368421  0.984136
#                        2019           4.6350        0.364850  0.628000
#                        2018           4.5710        0.256000  0.000000
#                        2016           4.5070        0.330240  0.955710
#
#                                health   freedom  generosity  government_trust  \
# ...

# %% [markdown]
# grouping the highest health by continent, country and year

# %%
df.groupby(["continent","Country","Year"]).max().sort_values(by="gdp_per_capita",ascending = False)
# Out:
#                                      happiness_score  gdp_per_capita  \
# continent Country              Year
# Asia      United Arab Emirates 2018           6.7740        2.096000
# Europe    Luxembourg           2015           6.8630        1.741944
#                                2019           6.8710        1.697520
# Asia      Singapore            2015           6.5720        1.692278
#                                2019           6.7390        1.645550
# ...                                              ...             ...
# Africa    Burundi              2019           2.9050        0.068310
#                                2017           3.7750        0.046000
#           Malawi               2016           4.2920        0.016040
#           Burundi              2016           2.9050        0.015300
#                                2020           3.7753        0.000000
#
#                                        family    health   freedom  generosity  \
# ...

# %% [markdown]
# grouping the highest gdp_per_capita by continent, country and year

# %%
agg_value = df.happiness_score.agg(["sum","mean","max"])
agg_value
# Out:
# sum     4334.861399
# mean       5.473310
# max        7.808700
# Name: happiness_score, dtype: float64

# %% [markdown]
# the total sum, mean and max of the happiness score

# %%
agg_value = df.health.agg(["sum","mean","max"])
agg_value
# Out:
# sum     513.763437
# mean      0.648691
# max       1.141000
# Name: health, dtype: float64

# %% [markdown]
# the total sum, mean and max of the health score

# %%
agg_value = df.gdp_per_capita.agg(["sum","mean","max"])
agg_value
# Out:
# sum     735.939918
# mean      0.929217
# max       2.096000
# Name: gdp_per_capita, dtype: float64

# %% [markdown]
# the total sum, mean and max of the  gdp_per_capita score

# %%
agg_value = df.generosity.agg(["sum","mean","max"])
agg_value
# Out:
# sum     168.252125
# mean      0.212440
# max       0.838075
# Name: generosity, dtype: float64

# %% [markdown]
# the total sum, mean and max of the  generosit score

# %%
agg_value = df.freedom.agg(["sum","mean","max"])
agg_value
# Out:
# sum     338.196967
# mean      0.427016
# max       0.724000
# Name: freedom, dtype: float64

# %% [markdown]
# the total sum, mean and max of the  freedom score

# %%
agg_value = df.government_trust.agg(["sum","mean","max"])
agg_value
# Out:
# sum     99.56986
# mean     0.12572
# max      0.55191
# Name: government_trust, dtype: float64

# %% [markdown]
# the total sum, mean and max of the  government_trust score

# %%
df[df["happiness_score"] == 7.808700] ["Country"]
# Out:
# Series([], Name: Country, dtype: object)

# %% [markdown]
# To know the country with the highwst happiness score

# %% [markdown]
# ###Visualization

# %%
from matplotlib import pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import seaborn as sns

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
import matplotlib.lines as mlines
import matplotlib.transforms as mtransforms

# %%
df
# Out:
#          Country  happiness_score  gdp_per_capita    family    health  \
# 0         Norway           7.5370        1.616463  1.533524  0.796667
# 1        Denmark           7.5220        1.482383  1.551122  0.792566
# 2        Iceland           7.5040        1.480633  1.610574  0.833552
# 3    Switzerland           7.4940        1.564980  1.516912  0.858131
# 4        Finland           7.4690        1.443572  1.540247  0.809158
# ..           ...              ...             ...       ...       ...
# 787     Botswana           3.4789        0.997549  0.000000  0.494102
# 788     Tanzania           3.4762        0.457163  0.000000  0.442678
# 789       Rwanda           3.3123        0.343243  0.000000  0.572383
# 790     Zimbabwe           3.2992        0.425564  0.000000  0.375038
# 791  Afghanistan           2.5669        0.300706  0.000000  0.266052
#
#       freedom  generosity  government_trust  dystopia_residual continent  \
# ...

# %%
df2020_unhappy = df[((df["happiness_score"] < 3.2) & (df["Year"] >= 2015))]
# sort dataframe

df2020_unhappy.sort_values(by=["happiness_score"], ascending=False, inplace=True)

sns.barplot(x = "happiness_score",
           y = "Country",
           data=df2020_unhappy,
palette = "coolwarm")

plt.title("Aggregate of unhappy countries between 2015 and 2020")

plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_6964\295697920.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2020_unhappy.sort_values(by=["happiness_score"], ascending=False, inplace=True)

# %% [markdown]
# aggregate of unhappy countries between 2015 - 20220

# %%
df2020_happy = df[((df["happiness_score"] > 7.3) & (df["Year"] >= 2015))]
# sort dataframe

df2020_unhappy.sort_values(by=["happiness_score"], ascending=False, inplace=True)

sns.barplot(x = "happiness_score",
           y = "Country",
           data=df2020_happy,
palette = "coolwarm")

plt.title("Aggregate of top 10  happy countries between 2015 and 2020")

plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_6964\3339551801.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2020_unhappy.sort_values(by=["happiness_score"], ascending=False, inplace=True)

# %% [markdown]
# visuals showing the top 10 happy countries betwwen 2015 - 2020

# %%
plt.figure(figsize=(16,7)),
sns.regplot(x='happiness_score', y='gdp_per_capita',data=df, color='blue')
# add custom line to the dataframe
plt.title("correlation between happiness-score and gdp_per_capita")
# Out:
# Text(0.5, 1.0, 'correlation between happiness-score and gdp_per_capita')

# %% [markdown]
# There is a positive correlation between  happiness and gdp_per_capita

# %%
plt.figure(figsize=(10,6)),
sns.lmplot(x='happiness_score', y='gdp_per_capita',data=df)

# %% [markdown]
# There is a positive correlation between  happiness and gdp_per_capita

# %%
plt.figure(figsize=(16,7)),
sns.regplot(x='happiness_score', y='health',data=df, color='blue')
# add custom line to the dataframe
plt.title("correlation between happiness-score and health")
# Out:
# Text(0.5, 1.0, 'correlation between happiness-score and health')

# %% [markdown]
# There is a positive correlation between  happiness and health

# %%
plt.figure(figsize=(16,7)),
sns.regplot(x='happiness_score', y='freedom',data=df, color='blue')
# add custom line to the dataframe
plt.title("correlation between happiness-score and freedom")
# Out:
# Text(0.5, 1.0, 'correlation between happiness-score and freedom')

# %% [markdown]
# There is a little or no correlation between  happiness and freedom

# %%
plt.figure(figsize=(16,7)),
sns.regplot(x='happiness_score', y='cpi_score',data=df, color='blue')
# add custom line to the dataframe
plt.title("correlation between happiness-score and cpi_score")
# Out:
# Text(0.5, 1.0, 'correlation between happiness-score and cpi_score')

# %% [markdown]
# There is a positive correlation between  happiness and cpi score

# %%
plt.figure(figsize=(16,7)),
sns.regplot(x='happiness_score', y='government_trust',data=df, color='blue')
# add custom line to the dataframe
plt.title("correlation between happiness-score and government_trust")
# Out:
# Text(0.5, 1.0, 'correlation between happiness-score and government_trust')

# %% [markdown]
# There is litle or no  correlation between  happiness and govenment trust

# %%
plt.figure(figsize=(16,7)),
sns.regplot(x='happiness_score', y='family',data=df, color='blue')
# add custom line to the dataframe
plt.title("correlation between happiness-score and family")
# Out:
# Text(0.5, 1.0, 'correlation between happiness-score and family')

# %% [markdown]
# There is  no  correlation between  happiness and family

# %%
plt.figure(figsize=(16,7)),
sns.regplot(x='health', y='gdp_per_capita',data=df, color='green')
# add custom line to the dataframe
plt.title("correlation between health and gdp_per_capita")
# Out:
# Text(0.5, 1.0, 'correlation between health and gdp_per_capita')

# %% [markdown]
# There is a positive correlation between health and gdp
# that is, one variable affects the other, as one increases the other increases too

# %%
plt.figure(figsize=(16,7)),
sns.regplot(x='health', y='freedom',data=df, color='purple')
# add custom line to the dataframe
plt.title("correlation between health and freedom")
# Out:
# Text(0.5, 1.0, 'correlation between health and freedom')

# %% [markdown]
# There is a no positive correlation between health and freedom
# that is, one variable does not affect the other

# %%
plt.figure(figsize=(16,7)),
sns.regplot(x='gdp_per_capita', y='freedom',data=df, color='purple')
# add custom line to the dataframe
plt.title("correlation between gdp_per_capita and freedom")
# Out:
# Text(0.5, 1.0, 'correlation between gdp_per_capita and freedom')

# %% [markdown]
# There is no  positive correlation between freedom and gdp
# that is, one variable affects the other, as one increases the other increases too

# %%
plt.figure(figsize=(16,7)),
sns.regplot(x='health', y='cpi_score',data=df, color='purple')
# add custom line to the dataframe
plt.title("correlation between health and cpi_score")
# Out:
# Text(0.5, 1.0, 'correlation between health and cpi_score')

# %% [markdown]
# There is a positive correlation between health and cpi score
# that is, one variable affects the other, as one increases the other increases too

# %%
plt.figure(figsize=(16,7)),
sns.regplot(x='gdp_per_capita', y='cpi_score',data=df, color='purple')
# add custom line to the dataframe
plt.title("correlation between gdp-per_capita and cpi_score")
# Out:
# Text(0.5, 1.0, 'correlation between gdp-per_capita and cpi_score')

# %% [markdown]
# There is a positive correlation between gdp_per_capita and cpi score
# that is, one variable affects the other, as one increases the other increases too

# %%
df
# Out:
#          Country  happiness_score  gdp_per_capita    family    health  \
# 0         Norway           7.5370        1.616463  1.533524  0.796667
# 1        Denmark           7.5220        1.482383  1.551122  0.792566
# 2        Iceland           7.5040        1.480633  1.610574  0.833552
# 3    Switzerland           7.4940        1.564980  1.516912  0.858131
# 4        Finland           7.4690        1.443572  1.540247  0.809158
# ..           ...              ...             ...       ...       ...
# 787     Botswana           3.4789        0.997549  0.000000  0.494102
# 788     Tanzania           3.4762        0.457163  0.000000  0.442678
# 789       Rwanda           3.3123        0.343243  0.000000  0.572383
# 790     Zimbabwe           3.2992        0.425564  0.000000  0.375038
# 791  Afghanistan           2.5669        0.300706  0.000000  0.266052
#
#       freedom  generosity  government_trust  dystopia_residual continent  \
# ...

# %%
A= df.groupby("continent")["happiness_score"].mean().sort_values(ascending = False)
A
# Out:
# continent
# Australia        7.289033
# North America    7.000539
# Europe           6.193717
# South America    5.865516
# Asia             5.267553
# Africa           4.353944
# Name: happiness_score, dtype: float64

# %%
A.plot(kind="pie", fontsize =10, shadow=True,autopct="%1.1f%%", wedgeprops={"edgecolor":"black"},startangle=90)
plt.title("percentages of the continent happiness score")
# Out:
# Text(0.5, 1.0, 'percentages of the continent happiness score')

# %%
A= df.groupby("continent")["happiness_score"].mean().sort_values(ascending = True)
A.plot(kind="barh", fontsize =14)
plt.title("continent by happiness_score")
# Out:
# Text(0.5, 1.0, 'continent by happiness_score')

# %%
B= df.groupby("Country")["happiness_score"].mean().sort_values(ascending = False)
B.head(5).plot(kind="bar", fontsize =14)
plt.title("Top 5 countries with the highest happiness_score")
# Out:
# Text(0.5, 1.0, 'Top 5 countries with the highest happiness_score')

# %%
C= df.groupby("Country")["happiness_score"].mean().sort_values(ascending = True)
C.head(5).plot(kind="barh", fontsize =10)
plt.title("Top 5 countries with the lowest happiness_score")
# Out:
# Text(0.5, 1.0, 'Top 5 countries with the lowest happiness_score')

# %%
D= df.groupby("continent")["health"].mean().sort_values(ascending = True)
D.plot(kind="barh", fontsize =14)
plt.title("continents by Health score")
# Out:
# Text(0.5, 1.0, 'continents by Health score')

# %%
D= df.groupby("Country")["health"].mean().sort_values(ascending = True)
D.head(5).plot(kind="barh", fontsize =14)
plt.title("Top 5 countries with lowest Health score")
# Out:
# Text(0.5, 1.0, 'Top 5 countries with lowest Health score')

# %%
E= df.groupby("Country")["health"].mean().sort_values(ascending = False)
E.head(5).plot(kind="barh", fontsize =14)
plt.title("countries with highest Health score")
# Out:
# Text(0.5, 1.0, 'countries with highest Health score')

# %%
F= df.groupby("continent")["gdp_per_capita"].mean().sort_values(ascending = True)
F.plot(kind="barh", fontsize =14)
plt.title("continent with gdp_per_capita")
# Out:
# Text(0.5, 1.0, 'continent with gdp_per_capita')

# %%
G= df.groupby("Country")["gdp_per_capita"].mean().sort_values(ascending = True)
G.head(5).plot(kind="barh", fontsize =14)
plt.title("Top 5 countries with lowest gdp_per_capita")
# Out:
# Text(0.5, 1.0, 'Top 5 countries with lowest gdp_per_capita')

# %%
G= df.groupby("Country")["gdp_per_capita"].mean().sort_values(ascending = False)
G.head(5).plot(kind="barh", fontsize =14)
plt.title("Top 5 countries with highest gdp_per_capita")
# Out:
# Text(0.5, 1.0, 'Top 5 countries with highest gdp_per_capita')

# %%
H= df.groupby("continent")["cpi_score"].mean().sort_values(ascending = True)
H.head(5).plot(kind="barh", fontsize =14)
plt.title("continent by cpi_score")
# Out:
# Text(0.5, 1.0, 'continent by cpi_score')

# %%
I= df.groupby("Country")["cpi_score"].mean().sort_values(ascending = False)
I.head(5).plot(kind="barh", fontsize =14)
plt.title("Top 5 Countries with the highest cpi_score")
# Out:
# Text(0.5, 1.0, 'Top 5 Countries with the highest cpi_score')

# %%
J= df.groupby("Country")["cpi_score"].mean().sort_values(ascending = True)
J.head(5).plot(kind="barh", fontsize =14)
plt.title("Top 5 Countries with the lowest cpi_score")
# Out:
# Text(0.5, 1.0, 'Top 5 Countries with the lowest cpi_score')

# %%
cat_tot= df.groupby("health")["gdp_per_capita"].sum().sort_values(ascending = False)
cat_tot.head(10)
# Out:
# health
# 0.999    6.597
# 0.874    4.922
# 0.815    4.687
# 0.828    4.114
# 0.861    3.866
# 0.808    3.814
# 0.884    3.664
# 0.785    3.067
# 0.896    2.906
# 0.657    2.855
# Name: gdp_per_capita, dtype: float64

# %%
import seaborn

# %%
data = [1412.167400, 1169.396699, 835.957300, 703.861900, 126.009700, 87.468400]
keys =['Europe', 'Asia', 'Africa', 'South America', 'North America', 'Australia' ]
palette_color = seaborn.color_palette('bright')
plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%')
plt.show()

# %%
cat_tot= df.groupby("continent")["gdp_per_capita"].sum().sort_values(ascending = False)
cat_tot
# Out:
# continent
# Europe           278.537974
# Asia             210.155631
# South America    104.588554
# Africa           103.225874
# North America     23.317200
# Australia         16.114685
# Name: gdp_per_capita, dtype: float64

# %% [markdown]
# Conclusion
#
# The analysis showed us that gdp_per_capita, Health amd Cpi score is related to Happiness, Because in fig 3.0,4.0 and 6.0, we found a positive correlation, as the happiness score, increases, these three variable scores increases.
#
# Also we did saw that the richer countrues(Finland, Norway,, Switzerland and Iceland) have a higher average level happiness score, Healthier countries too have happier population.
#
# Furthermore, Wealtheir countries have the lowest cpi score which also contributes into a happier life, healtheir countries tends to be wealthy as seen in fig 10.0.
#
# The Analysis also shows that AFRICA as  a continent has the lowest happiness score, highest cpi score, low health score and also gdp per capita score. Which means, Africa needs to invest in its health sector, curb corruption and work on their economy in order to make her citizens happy as seen in fig 15.0.
#
# RECOMMENDATION.
#
# As a nigerian and Afriacn, the government of most African countries needs to come together and implement strict rules on corruption that will help reduce the way at which the government officials steal public funds meant to be used for the growth and development of the country. African countries needs to invest in their health sector because health is an important factor that contributes into happiness score.A healthier life is eauals to a happy life. They also need to improve their economy making more exports, grow more agricultural products that will attract foreign investors.
